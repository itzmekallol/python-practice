# %%
print("""My name is Kallol.I am learning Python.This is my 3rd day of coding.""")

# %%
name = "Kallol"age = 20city = "Kolkata"print("Name:", name)print("Age:", age)print("City:", city)

# %%
a = 15b = 4addition = a + bsubtraction = a - bmultiplication = a * bdivision = a / bfloor_division = a // bmodulus = a % bexponent = a ** bprint("Addition:", addition)print("Subtraction:", subtraction)print("Multiplication:", multiplication)print("Division:", division)print("Floor Division:", floor_division)print("Modulus:", modulus)print("Exponent:", exponent)

# %%
name = input("Enter your name: ")age = input("Enter your age: ")print(f"Hello {name}!")print(f"You are {age} years old.")print("Welcome to Python.")

# %%
name = "Kallol"age = 20height = 5.8is_student = Trueprint(name, type(name))print(age, type(age))print(height, type(height))print(is_student, type(is_student))

# %%
age = int(input("Enter your age: "))print(age, type(age))

# %%
first_num = int(input("Enter first number: "))second_num = int(input("Enter second number: "))total = (first_num + second_num)print(f"The sum is: {total}")

# %%
num = int(input("Enter a number: "))if num % 2 == 0:    print("The number is Even.")else:    print("The number is Odd.")

# %%
first_num = int(input("Enter first number: "))second_num = int(input("Enter second number: "))if first_num > second_num:    print("First number is larger.")elif second_num > first_num:    print("Second number is larger.")else:    print("Both numbers are equal.")
